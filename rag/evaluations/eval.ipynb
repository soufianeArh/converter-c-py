# %%
import  test_loader

# %%
tests = test_loader.load_tests()

# %%
example=tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# When was Insurellm founded?
# direct_fact
# Insurellm was founded in 2015.
# ['2015', 'founded']

# %%
from collections import Counter
count = Counter[str]([t.category for t in tests])
print(count)
# Out:
# Counter({'direct_fact': 34, 'temporal': 11, 'spanning': 10, 'relationship': 6, 'comparative': 5, 'holistic': 5, 'numerical': 4})

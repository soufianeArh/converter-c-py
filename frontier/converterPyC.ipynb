# %%
import os
import io
import sys
from dotenv  import load_dotenv
from openai import OpenAI
import google.generativeai
import anthropic
from IPython.display import Markdown, display, update_display
import gradio as gr
import subprocess
from dotenv import load_dotenv

# %%
load_dotenv()

openai_api_key = os.getenv("OPENAI_API_KEY")
claude_api_key = os.getenv("ANTHROPIC_API_KEY")
gemini_api_key = os.getenv("GOOGLE_API_KEY")

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if claude_api_key:
    print(f"Anthropic API Key exists and begins {claude_api_key[:7]}")
else:
    print("Anthropic API Key not set")

if gemini_api_key:
    print(f"Google API Key exists and begins {gemini_api_key[:8]}")
else:
    print("Google API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AIzaSyAB

# %%
openai = OpenAI()

chatgpt_url= "https://api.openai.com/v1/chat/completions"
claude_url = "https://api.anthropic.com/v1"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/"

chatgpt_client= OpenAI(api_key=openai_api_key, base_url=chatgpt_url)
claude_client= OpenAI(api_key=openai_api_key, base_url=claude_url)
gemini_client= OpenAI(api_key=openai_api_key, base_url=gemini_url)

# %%
#models to be used
CHATGPT_MODEL="gpt-5"
CLAUDE_MODEL="claude-sonnet-4-20250514"
GEMINI_MODEL="gpt-5"
